# %% [markdown]
# ## Now that all the files have complete GuanoMD from the last step, we need to pull these into the Bulk Upload forms that can be uploaded to NABat

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import nabatpy

# %% [markdown]
# ### This notebook used to be quite a bit more complex, but the code was moved into the nabatpy package for more robust maintenance and reuse.  The individual functions such as get row from GuanoMD and GuanoMD to dataframe are available from the package directly, but get called recursively from this generate_bulkupload function

# %%
_ = nabatpy.utils.generate_bulkupload(r"D:\CNHP_Output", use_previous=False)
# Out:
# Starting on D:\CNHP_Output\2016\1005\NE
# [########################################] | 100% Completed | 14.8s
# [########################################] | 100% Completed |  0.9s
# Starting on D:\CNHP_Output\2016\1005\NW
# [########################################] | 100% Completed | 16.4s
# [########################################] | 100% Completed |  0.3s
# Starting on D:\CNHP_Output\2016\1026\NW
# [########################################] | 100% Completed |  7.3s
# [########################################] | 100% Completed |  0.2s
# Starting on D:\CNHP_Output\2016\1026\SW
# [########################################] | 100% Completed |  6.8s
# [########################################] | 100% Completed |  0.2s
# Starting on D:\CNHP_Output\2016\1085\NW
# [########################################] | 100% Completed |  7.5s
# [########################################] | 100% Completed |  0.2s
# Starting on D:\CNHP_Output\2016\1085\SE
# ...
